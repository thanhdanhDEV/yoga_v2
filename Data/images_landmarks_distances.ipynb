# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path_distances = '3d_distances.csv'
path_landmarks= 'landmarks.csv'
df_distances = pd.read_csv(path_distances)
df_landmarks = pd.read_csv(path_landmarks)


df_distances.drop(columns=["pose_id"], inplace=True) 
df_landmarks.drop(columns=["pose_id"], inplace=True)

# %%
### get list of columns : df_distances
name_distances = list(df_distances.columns)
print(len(name_distances))
for item in name_distances:
    print(item)
# Out:
# 16
# left_shoulder_left_wrist
# right_shoulder_right_wrist
# left_hip_left_ankle
# right_hip_right_ankle
# left_hip_left_wrist
# right_hip_right_wrist
# left_shoulder_left_ankle
# right_shoulder_right_ankle
# left_hip_right_wrist
# right_hip_left_wrist
# left_elbow_right_elbow
# left_knee_right_knee
# left_wrist_right_wrist
# left_ankle_right_ankle
# left_hip_avg_left_wrist_left_ankle
# right_hip_avg_right_wrist_right_ankle

# %%
import numpy as np

def cal_distances(point_1, point_2):
    # [x1_coords, y1_coords, z1_coords] = [ -5.889507, -57.63752, -45.01975]
    # [x2_coords, y2_coords, z2_coords] = [ -4.656085, -62.832863, -44.571823]
    p1 = np.array([point_1[0], point_1[1], point_1[2]])
    p2 = np.array([point_2[0], point_2[1], point_2[2]])

    squared_dist = np.sum((p1-p2)**2, axis=0)
    dist = np.sqrt(squared_dist)
    return dist

# %%
# Importing Pandas to create DataFrame
import pandas as pd
  
# Creating Empty DataFrame and Storing it in variable df
df_out_distances = pd.DataFrame()
  
# Printing Empty DataFrame
# print(df_out_distances)
input_cal = 'left_shoulder_left_wrist'


def create_dist_Series(dist_between_string):
    ### split string
    index = dist_between_string.find("_", int(len(dist_between_string)/2 - 2), -1) ### find underscore in mid string
    A_point = dist_between_string[:index]
    B_point = dist_between_string[index+1:]

    # Define the function
    def norm_2(point_1, point_2):
        A = [point_1[0], point_1[1], point_1[2]]
        B = [point_2[0], point_2[1], point_2[2]]
        dist = cal_distances(point_1= A, point_2= B)
        return dist

    # Apply the function to the DataFrame
    out_distances = df_landmarks.apply(lambda row: norm_2(row[['x_'+A_point, 'y_'+A_point, 'z_'+A_point]], row[['x_'+B_point, 'y_'+B_point, 'z_'+B_point]]), axis=1)
    return out_distances
df_out_distances[input_cal] = create_dist_Series(input_cal)
df_out_distances
# Out:
#       left_shoulder_left_wrist
# 0                    38.423302
# 1                    65.631511
# 2                    69.661672
# 3                    52.437597
# 4                    30.867631
# ...                        ...
# 1367                 40.593422
# 1368                 39.974774
# 1369                 45.298246
# 1370                 45.043042
# 1371                 32.080089
#
# [1372 rows x 1 columns]

# %%
### get list of columns : df_distances

def create_dist_Series(dist_between_string):
    ### split string
    index = dist_between_string.find("_", int(len(dist_between_string)/2 - 2), -1) ### find underscore in mid string
    A_point = dist_between_string[:index]
    B_point = dist_between_string[index+1:]

    # Define the function
    def norm_2(point_1, point_2):
        A = [point_1[0], point_1[1], point_1[2]]
        B = [point_2[0], point_2[1], point_2[2]]
        dist = cal_distances(point_1= A, point_2= B)
        return dist

    # Apply the function to the DataFrame
    out_distances = df_landmarks.apply(lambda row: norm_2(row[['x_'+A_point, 'y_'+A_point, 'z_'+A_point]], row[['x_'+B_point, 'y_'+B_point, 'z_'+B_point]]), axis=1)
    return out_distances

def create_avg_dist(avg_between_string):
    index = avg_between_string.find("avg_") ### find avg_ in mid string
    A_point = avg_between_string[:index-1]
    other = avg_between_string[index+4:]

    sub_str = other
    index = sub_str.find("_", int(len(sub_str)/2 - 2), -1) ### find underscore in mid string
    B_point = sub_str[:index]
    C_point = sub_str[index+1:]
    def avg_(row):
        return (row[A_point+ '_' + B_point] + row[A_point+ '_' + C_point]) /2

    # Apply the function to the DataFrame
    out_distances = df_out_distances.apply(lambda row: avg_(row), axis= 1)
    return out_distances

# Importing Pandas to create DataFrame
import pandas as pd
  
# Creating Empty DataFrame and Storing it in variable df
df_out_distances = pd.DataFrame()

name_distances = list(df_distances.columns)
"""
name_distances = ['left_shoulder_left_wrist',
                'right_shoulder_right_wrist',
                'left_hip_left_ankle',
                'right_hip_right_ankle',
                'left_hip_left_wrist',
                'right_hip_right_wrist',
                'left_shoulder_left_ankle',
                'right_shoulder_right_ankle',
                'left_hip_right_wrist',
                'right_hip_left_wrist',
                'left_elbow_right_elbow',
                'left_knee_right_knee',
                'left_wrist_right_wrist',
                'left_ankle_right_ankle',
                'left_hip_avg_left_wrist_left_ankle',
                'right_hip_avg_right_wrist_right_ankle']
"""
for i in  range(len(name_distances)):
    index = name_distances[i].find("avg_")
    if index == -1:
        df_out_distances[name_distances[i]] = create_dist_Series(name_distances[i])
    else:
        df_out_distances[name_distances[i]] = create_avg_dist(name_distances[i])

# ### split string
# for i in  range(len(name_distances) - 2):
#     df_out_distances[name_distances[i]] = create_dist_Series(name_distances[i])

# for item in name_distances[-2:]:
#     # Apply the function to the DataFrame
#     df_out_distances[item] = create_avg_dist(item)

df_out_distances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   left_shoulder_left_wrist               1372 non-null   float64
#  1   right_shoulder_right_wrist             1372 non-null   float64
#  2   left_hip_left_ankle                    1372 non-null   float64
#  3   right_hip_right_ankle                  1372 non-null   float64
#  4   left_hip_left_wrist                    1372 non-null   float64
#  5   right_hip_right_wrist                  1372 non-null   float64
#  6   left_shoulder_left_ankle               1372 non-null   float64
#  7   right_shoulder_right_ankle             1372 non-null   float64
#  8   left_hip_right_wrist                   1372 non-null   float64
#  9   right_hip_left_wrist                   1372 non-null   float64
#  10  left_elbow_right_elbow                 1372 non-null   float64
#  11  left_knee_right_knee                   1372 non-null   float64
#  12  left_wrist_right_wrist                 1372 non-null   float64
#  13  left_ankle_right_ankle                 1372 non-null   float64
#  14  left_hip_avg_left_wrist_left_ankle     1372 non-null   float64
#  15  right_hip_avg_right_wrist_right_ankle  1372 non-null   float64
# dtypes: float64(16)
# memory usage: 171.6 KB

# %%
### split string
for item in name_distances[-2:]:
    index = item.find("avg_") ### find avg_ in mid string
    A_point = item[:index-1]
    other = item[index+4:]

    sub_str = other
    index = sub_str.find("_", int(len(sub_str)/2 - 2), -1) ### find underscore in mid string
    B_point = sub_str[:index]
    C_point = sub_str[index+1:]
    def avg_(row):
        return (row[A_point+ '_' + B_point] + row[A_point+ '_' + C_point]) /2

    # Apply the function to the DataFrame
    df_out_distances[item] = df_out_distances.apply(lambda row: avg_(row), axis= 1)

# %%
name_distances[-1]
index = name_distances[2].find("avg_")
print(index)
# Out:
# -1

# %% [markdown]
# # Code final

# %%
### get list of columns : df_distances

def create_dist_Series(dist_between_string):
    ### split string
    index = dist_between_string.find("_", int(len(dist_between_string)/2 - 2), -1) ### find underscore in mid string
    A_point = dist_between_string[:index]
    B_point = dist_between_string[index+1:]

    # Define the function
    def norm_2(point_1, point_2):
        A = [point_1[0], point_1[1], point_1[2]]
        B = [point_2[0], point_2[1], point_2[2]]
        dist = cal_distances(point_1= A, point_2= B)
        return dist

    # Apply the function to the DataFrame
    out_distances = df_landmarks.apply(lambda row: norm_2(row[['x_'+A_point, 'y_'+A_point, 'z_'+A_point]], row[['x_'+B_point, 'y_'+B_point, 'z_'+B_point]]), axis=1)
    return out_distances

def create_avg_dist(avg_between_string):
    index = avg_between_string.find("avg_") ### find avg_ in mid string
    A_point = avg_between_string[:index-1]
    other = avg_between_string[index+4:]

    sub_str = other
    index = sub_str.find("_", int(len(sub_str)/2 - 2), -1) ### find underscore in mid string
    B_point = sub_str[:index]
    C_point = sub_str[index+1:]
    def avg_(row):
        return (row[A_point+ '_' + B_point] + row[A_point+ '_' + C_point]) /2

    # Apply the function to the DataFrame
    out_distances = df_out_distances.apply(lambda row: avg_(row), axis= 1)
    return out_distances

# Importing Pandas to create DataFrame
import pandas as pd
  
# Creating Empty DataFrame and Storing it in variable df
df_out_distances = pd.DataFrame()

name_distances = list(df_distances.columns)
"""
name_distances = ['left_shoulder_left_wrist',
                'right_shoulder_right_wrist',
                'left_hip_left_ankle',
                'right_hip_right_ankle',
                'left_hip_left_wrist',
                'right_hip_right_wrist',
                'left_shoulder_left_ankle',
                'right_shoulder_right_ankle',
                'left_hip_right_wrist',
                'right_hip_left_wrist',
                'left_elbow_right_elbow',
                'left_knee_right_knee',
                'left_wrist_right_wrist',
                'left_ankle_right_ankle',
                'left_hip_avg_left_wrist_left_ankle',
                'right_hip_avg_right_wrist_right_ankle']
"""
for i in  range(len(name_distances)):
    index = name_distances[i].find("avg_")
    if index == -1:
        df_out_distances[name_distances[i]] = create_dist_Series(name_distances[i])
    else:
        df_out_distances[name_distances[i]] = create_avg_dist(name_distances[i])

df_out_distances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   left_shoulder_left_wrist               1372 non-null   float64
#  1   right_shoulder_right_wrist             1372 non-null   float64
#  2   left_hip_left_ankle                    1372 non-null   float64
#  3   right_hip_right_ankle                  1372 non-null   float64
#  4   left_hip_left_wrist                    1372 non-null   float64
#  5   right_hip_right_wrist                  1372 non-null   float64
#  6   left_shoulder_left_ankle               1372 non-null   float64
#  7   right_shoulder_right_ankle             1372 non-null   float64
#  8   left_hip_right_wrist                   1372 non-null   float64
#  9   right_hip_left_wrist                   1372 non-null   float64
#  10  left_elbow_right_elbow                 1372 non-null   float64
#  11  left_knee_right_knee                   1372 non-null   float64
#  12  left_wrist_right_wrist                 1372 non-null   float64
#  13  left_ankle_right_ankle                 1372 non-null   float64
#  14  left_hip_avg_left_wrist_left_ankle     1372 non-null   float64
#  15  right_hip_avg_right_wrist_right_ankle  1372 non-null   float64
# dtypes: float64(16)
# memory usage: 171.6 KB
